# %%
import gdown
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4480\2473267647.py in <module>
# ----> 1 import gdown
#
# c:\Users\Rajaas\anaconda3\envs\waste\lib\site-packages\gdown\__init__.py in <module>
#       2
#       3 from . import exceptions
# ----> 4 from .cached_download import cached_download
#       5 from .cached_download import md5sum
#       6 from .download import download
#
# c:\Users\Rajaas\anaconda3\envs\waste\lib\site-packages\gdown\cached_download.py in <module>
#      10 import filelock
#      11
# ---> 12 from .download import download
#      13
#      14 cache_root = osp.join(osp.expanduser("~"), ".cache/gdown")
#
# c:\Users\Rajaas\anaconda3\envs\waste\lib\site-packages\gdown\download.py in <module>
#      11 import time
#      12
# ---> 13 import requests
#      14 import six
#      15 import tqdm
#
# c:\Users\Rajaas\anaconda3\envs\waste\lib\site-packages\requests\__init__.py in <module>
#      41 import warnings
#      42
# ---> 43 import urllib3
#      44
#      45 from .exceptions import RequestsDependencyWarning
#
# c:\Users\Rajaas\anaconda3\envs\waste\lib\site-packages\urllib3\__init__.py in <module>
#      40     elif ssl.OPENSSL_VERSION_INFO < (1, 1, 1):  # Defensive:
#      41         raise ImportError(
# ---> 42             "urllib3 v2.0 only supports OpenSSL 1.1.1+, currently "
#      43             f"the 'ssl' module is compiled with {ssl.OPENSSL_VERSION!r}. "
#      44             "See: https://github.com/urllib3/urllib3/issues/2168"
#
# ImportError: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'OpenSSL 1.1.0h  27 Mar 2018'. See: https://github.com/urllib3/urllib3/issues/2168

# %%
pip install urllib3==1.26.18
# Out:
# Collecting urllib3==1.26.18
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ------------------------------------ 143.8/143.8 kB 856.4 kB/s eta 0:00:00
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed urllib3-1.26.18
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown

# %%
import os

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'd:\\DataScience Projects\\Waste-Detection-System-using-Yolo-v5'

# %%
url = 'https://drive.google.com/file/d/1UlMVv0-k-LpglQOgr7qWctwkJ2COWeQh/view?usp=sharing'

# %%
file_id = url.split('/')
file_id
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1UlMVv0-k-LpglQOgr7qWctwkJ2COWeQh',
#  'view?usp=sharing']

# %%
file_id = url.split('/')[-2]
file_id
# Out:
# '1UlMVv0-k-LpglQOgr7qWctwkJ2COWeQh'

# %%
prefix = 'https://drive.google.com/uc?export=download&id='
gdown.download(prefix + file_id,'data/waste_data.zip')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1UlMVv0-k-LpglQOgr7qWctwkJ2COWeQh
# From (redirected): https://drive.google.com/uc?export=download&id=1UlMVv0-k-LpglQOgr7qWctwkJ2COWeQh&confirm=t&uuid=04694fac-bb4b-46cf-8e54-244929464cb4
# To: d:\DataScience Projects\Waste-Detection-System-using-Yolo-v5\data\waste_data.zip
# 100%|██████████| 40.1M/40.1M [00:10<00:00, 3.77MB/s]
# 'data/waste_data.zip'
